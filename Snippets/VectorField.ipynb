# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1,1,10)
y = np.linspace(-1,1,10)

# %%
xo, yo = np.meshgrid(x,y)

# %%
# This is the vector field generated by the differential equations system
# dx/dt = y, dy/dt = sin(x) 

q = plt.quiver(xo,yo, yo, -np.sin(xo))
